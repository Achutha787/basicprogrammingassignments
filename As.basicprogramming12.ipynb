# %%
#1)Write a Python program to Extract Unique values dictionary values?
def dictuniquevalues(d1):
    '''function to extract unique dictionary values'''
    values= set(d1.values())
    return values
dictuniquevalues({"1":"200","2":"200","3":"200"})
# Out:
# {'200'}

# %%
#2)Write a Python program to find the sum of all items in a dictionary?
d2 = {'Apple':10,'Mango':20,'Banana':30,'Guava':40,'PineApple':200}
print('Sum of All items: ', sum(d2.values()))
# Out:
# Sum of All items:  300

# %%
#3)Write a Python program to Merging two Dictionaries
def mergetwodictionaries(d4,d5):
    '''function to merge two dictionaries'''
    d4.update(d5)
print(d4)
mergetwodictionaries({"1":"200","2":"200","3":"200"},{"achu":"ineuron","spoo":"achutha"})
# Out:
# {'1': '200', '2': '200', '3': '200', 'achu': 'ineuron', 'spoo': 'achutha'}

# %%
#4)Write a Python program to convert key-values list to flat dictionary?
def flatdict(d6):
    '''function  to convert keyvalues list to flat dictionary'''
    print(dict(d6))
    
flatdict([("a",100),("b",200),("c",300),("d",400)])
# Out:
# {'a': 100, 'b': 200, 'c': 300, 'd': 400}

# %%
#5)Write a Python program to insertion at the beginning in OrderedDict?
from collections import OrderedDict
dictone = OrderedDict({"stephen":'Iphone','billgates':'Windows','browser':'chrome'})
print('dictone',dictone)
dicttwo = {'discovery':'SpaceX'}
dictone.update(dicttwo)
print('dictone',dictone)
dictone.move_to_end('Tesla',last=False)
print('dictone',dictone)
# Out:
# dictone OrderedDict([('stephen', 'Iphone'), ('billgates', 'Windows'), ('browser', 'chrome')])
# dictone OrderedDict([('stephen', 'Iphone'), ('billgates', 'Windows'), ('browser', 'chrome'), ('discovery', 'SpaceX')])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5732/1313449403.py in <module>
#       6 dictone.update(dicttwo)
#       7 print('dictone',dictone)
# ----> 8 dictone.move_to_end('Tesla',last=False)
#       9 print('dictone',dictone)
#
# KeyError: 'Tesla'

# %%
#6)Write a Python program to check order of character in string using OrderedDict()?
from collections import OrderedDict
initialist = {'a': 1000, 'f': 200, 'd': 300, 'c': 400, 'b': 500, 'e': 600}
print(initialist)

finalist = OrderedDict(dict(sorted(initialist.items())))
print(finalist)
# Out:
# {'a': 1000, 'f': 200, 'd': 300, 'c': 400, 'b': 500, 'e': 600}
# OrderedDict([('a', 1000), ('b', 500), ('c', 400), ('d', 300), ('e', 600), ('f', 200)])

# %%
#7)Write a Python program to sort Python Dictionaries by Key or Value?
d_items = {'Mango':100,'PineApple':22,'Banana':60,'Grape':13}
def sort_dict(in_dict,sort_type):
    if sort_type == 'key':
        print(dict(sorted(in_dict.items(), key=lambda x:x[0], reverse=False)))
    else:
        print(dict(sorted(in_dict.items(), key=lambda x:x[1], reverse=False)))
        
sort_dict(d_items,'key')        
sort_dict(d_items,'value')
# Out:
# {'Banana': 60, 'Grape': 13, 'Mango': 100, 'PineApple': 22}
# {'Grape': 13, 'PineApple': 22, 'Banana': 60, 'Mango': 100}
